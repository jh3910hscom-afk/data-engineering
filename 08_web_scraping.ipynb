# %%
import requests  # [+] HTTP 요청
from bs4 import BeautifulSoup  # [+] 웹스크래핑
import pandas as pd

# %%
# 1. User-Agent 설정
# 우리가 실제 크롬 브라우저를 사용하는 일반 사용자인 것처럼 서버를 속이는 '위장 신분증' 역할
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

search_keyword = '날씨'  # [+] 검색 키워드
url = f'https://search.naver.com/search.naver?where=news&query={search_keyword}'  # 검색한 웹페이지 주소

# %%
# 2. 페이지 요청 및 파싱
res = requests.get(url, headers=headers)  # [+] 네이버 서버에 페이지 정보 요청(GET)
res.raise_for_status() # 서버가 응답을 잘 주었는지 확인(정상 200, 페이지 없음 404 등)
soup = BeautifulSoup(res.text, 'html.parser')  # [+] BeautifulSoup 객체 생성

# %%
# 3. 질문자님이 찾은 클래스로 타겟팅 (띄어쓰기를 '.'으로 변경)
# [+] 찾고자 하는 HTML 태그 정의
target_class = "span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1.sds-comps-text-type-headline1"
title_spans = soup.select(target_class) # [+] 조건에 맞는 모든 태그를 찾아 리스트로 저장

extracted_data = []

# %%
title_spans[0].text.strip()
# Out:
# "서울 한낮 27도 '초여름 더위'…제주·남해안 비[오늘날씨]"

# %%
# 4. 데이터 추출
for span in title_spans:
    # [+] 기사 제목 추출
    title = span.text.strip()
    
    # [+] 기사 링크 추출: 제목(span)을 클릭 가능하게 만드는 부모 <a> 태그를 역추적하여 찾음
    parent_a_tag = span.find_parent("a")
    link = parent_a_tag['href'] if parent_a_tag and parent_a_tag.has_attr('href') else "링크 없음"
    
    extracted_data.append({
        '제목': title,
        '링크': link
    })

# %%
# 5. [+] DataFrame으로 변환 및 확인
df = pd.DataFrame(extracted_data)
print(f"총 {len(df)}개의 기사를 추출했습니다.\n")
display(df)
# Out:
# 총 10개의 기사를 추출했습니다.
#                                               제목  \
# 0              서울 한낮 27도 '초여름 더위'…제주·남해안 비[오늘날씨]
# 1  '낮 최고 26도' 포근한 봄날 이어져...환절기 더욱 피곤한 이유는 [오늘...
# 2       경량패딩·반팔이 한자리에…"케데헌에서 봤다고요? 이게 한국 날씨입니...
# 3         [날씨] 한낮 초여름 날씨, 서울 최고 28℃...동해안 비교적 선선
# 4                [내일날씨] 낮 최고 27도 초여름 날씨…큰 일교차 주의
# 5                “벌써 초여름?” 한낮 최고 기온 28도 [오늘의 날씨]
# 6                      초여름 날씨, 짧아진 옷차림 [한강로 사진관]
# 7                  [내일날씨] 낮 기온 30도 육박…초여름 날씨 이어져
# 8             4월 초인데 낮 기온 30도 육박…초여름 날씨 기록한 이 동네
# 9               낮 최고 28도 '초여름 날씨'…큰 일교차 주의[내일날씨]
#
#                                                   링크
# 0  https://www.newsis.com/view/NISX20260413_00035...
# 1  https://www.dailian.co.kr/news/view/1633546/?s...
# 2  http://weekly.chosun.com/news/articleView.html...
# 3  https://www.ytn.co.kr/_ln/0108_202604141309345254
# 4  https://www.yna.co.kr/view/AKR2026041400710000...
# 5  https://www.sedaily.com/article/20031985?ref=n...
# 6  https://www.segye.com/newsView/20260414519846?...
# 7                http://www.inews24.com/view/1960261
# 8              https://www.mk.co.kr/article/12015627
# 9  https://www.newsis.com/view/NISX20260413_00035...
